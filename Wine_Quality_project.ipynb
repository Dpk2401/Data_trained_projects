# %%
import pandas as pd

# %%
df = pd.read_csv("winequality-red.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#scatterplot

import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="fixed acidity", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(x="volatile acidity", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
sns.scatterplot(x="citric acid", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
sns.scatterplot(x="residual sugar", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(x="chlorides", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
sns.scatterplot(x="free sulfur dioxide", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x="total sulfur dioxide", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x="density", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
sns.scatterplot(x="pH", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.scatterplot(x="sulphates", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
sns.scatterplot(x="alcohol", y="quality", data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
#correlation of function
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
plt.figure(figsize = (15,7))
sns.heatmap(df.corr(), annot = True, linewidths = 0.5, linecolor = 'Blue', fmt = '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Describe the dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
round(df.describe().transpose(), 2)
# Out:
#                        count   mean    std   min    25%    50%    75%     max
# fixed acidity         1599.0   8.32   1.74  4.60   7.10   7.90   9.20   15.90
# volatile acidity      1599.0   0.53   0.18  0.12   0.39   0.52   0.64    1.58
# citric acid           1599.0   0.27   0.19  0.00   0.09   0.26   0.42    1.00
# residual sugar        1599.0   2.54   1.41  0.90   1.90   2.20   2.60   15.50
# chlorides             1599.0   0.09   0.05  0.01   0.07   0.08   0.09    0.61
# free sulfur dioxide   1599.0  15.87  10.46  1.00   7.00  14.00  21.00   72.00
# total sulfur dioxide  1599.0  46.47  32.90  6.00  22.00  38.00  62.00  289.00
# density               1599.0   1.00   0.00  0.99   1.00   1.00   1.00    1.00
# pH                    1599.0   3.31   0.15  2.74   3.21   3.31   3.40    4.01
# sulphates             1599.0   0.66   0.17  0.33   0.55   0.62   0.73    2.00
# alcohol               1599.0  10.42   1.07  8.40   9.50  10.20  11.10   14.90
# quality               1599.0   5.64   0.81  3.00   5.00   6.00   6.00    8.00

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(), 2), linewidth=2, annot=True, fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol, 3*ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows, ncol, i+1)
    sns.boxplot(df[collist[i]], color='green', orient='h')
    plt.tight_layout()

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# ## Normal Distribution curve

# %%
sns.distplot(df['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(df['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(df['residual sugar'])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(df['chlorides'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(df['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df['total sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
sns.distplot(df['pH'])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.distplot(df['sulphates'])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.distplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# ## Data Cleaning
#
# Data preprocessing

# %%
df.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
delete=pd.DataFrame([['0.124052','fixed acidity', 'No', 'Alot'], ['-0.390558', 'volatile acidity', 'No', 'Alot']], columns=['Corelation with Target', 'Column Name', 'Normalised', 'Outliers'])
delete
# Out:
#   Corelation with Target       Column Name Normalised Outliers
# 0               0.124052     fixed acidity         No     Alot
# 1              -0.390558  volatile acidity         No     Alot

# %%
df = df.drop(['fixed acidity', 'volatile acidity'], axis = 1)

# %%
df
# Out:
#       citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0            0.00             1.9      0.076                 11.0
# 1            0.00             2.6      0.098                 25.0
# 2            0.04             2.3      0.092                 15.0
# 3            0.56             1.9      0.075                 17.0
# 4            0.00             1.9      0.076                 11.0
# ...           ...             ...        ...                  ...
# 1594         0.08             2.0      0.090                 32.0
# 1595         0.10             2.2      0.062                 39.0
# 1596         0.13             2.3      0.076                 29.0
# 1597         0.12             2.0      0.075                 32.0
# 1598         0.47             3.6      0.067                 18.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                     34.0  0.99780  3.51       0.56      9.4        5
# 1                     67.0  0.99680  3.20       0.68      9.8        5
# 2                     54.0  0.99700  3.26       0.65      9.8        5
# 3                     60.0  0.99800  3.16       0.58      9.8        6
# 4                     34.0  0.99780  3.51       0.56      9.4        5
# ...                    ...      ...   ...        ...      ...      ...
# 1594                  44.0  0.99490  3.45       0.58     10.5        5
# 1595                  51.0  0.99512  3.52       0.76     11.2        6
# 1596                  40.0  0.99574  3.42       0.75     11.0        6
# 1597                  44.0  0.99547  3.57       0.71     10.2        5
# 1598                  42.0  0.99549  3.39       0.66     11.0        6
#
# [1599 rows x 10 columns]

# %% [markdown]
# ## Removing outliers
#
# Z-Score Technique

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 10)

# %%
threshold=3    #rule of thumb
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   42,   43,   45,
#          57,   81,   81,   83,   86,   88,   91,   92,   95,  106,  106,
#         109,  142,  144,  147,  151,  151,  151,  151,  163,  164,  169,
#         169,  181,  226,  226,  240,  258,  258,  274,  281,  291,  324,
#         325,  339,  340,  354,  396,  396,  400,  400,  442,  451,  459,
#         467,  480,  480,  494,  515,  517,  554,  555,  557,  568,  584,
#         588,  591,  595,  608,  614,  636,  639,  649,  649,  651,  652,
#         652,  672,  684,  690,  692,  692,  695,  723,  730,  754,  776,
#         777,  795,  821,  832,  836,  837,  889,  899,  911,  917,  923,
#         925,  926,  982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079,
#        1079, 1081, 1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231,
#        1235, 1244, 1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288, 1289,
#        1295, 1296, 1299, 1300, 1316, 1319, 1319, 1321, 1358, 1367, 1370,
#        1370, 1372, 1372, 1374, 1374, 1434, 1434, 1434, 1435, 1435, 1435,
#        1469, 1474, 1474, 1474, 1476, 1476, 1476, 1478, 1493, 1496, 1505,
#        1558, 1558, 1570, 1574, 1589], dtype=int64), array([7, 3, 3, 4, 2, 7, 2, 1, 2, 7, 6, 3, 2, 7, 2, 7, 7, 7, 7, 6, 2, 7,
#        4, 8, 8, 2, 0, 2, 6, 7, 1, 1, 2, 7, 2, 2, 7, 2, 2, 7, 1, 2, 2, 1,
#        1, 7, 7, 4, 1, 3, 1, 3, 5, 2, 9, 8, 1, 5, 1, 4, 9, 5, 5, 5, 2, 3,
#        8, 4, 1, 5, 7, 4, 7, 1, 4, 4, 1, 8, 4, 4, 9, 2, 7, 6, 7, 2, 2, 2,
#        2, 7, 8, 9, 5, 5, 5, 9, 1, 1, 1, 3, 3, 3, 5, 5, 1, 2, 7, 1, 1, 1,
#        4, 1, 4, 6, 5, 3, 3, 2, 3, 1, 3, 1, 1, 3, 4, 2, 5, 8, 5, 8, 7, 7,
#        3, 3, 9, 6, 6, 2, 7, 6, 3, 7, 2, 7, 2, 7, 2, 9, 1, 3, 5, 1, 3, 5,
#        9, 1, 3, 5, 1, 3, 5, 9, 4, 4, 9, 2, 3, 2, 1, 1], dtype=int64))

# %%
len(np.where(z>3) [0])
# Out:
# 170

# %%
z.iloc[4]
# Out:
# citric acid             1.391472
# residual sugar          0.453218
# chlorides               0.243707
# free sulfur dioxide     0.466193
# total sulfur dioxide    0.379133
# density                 0.558274
# pH                      1.288643
# sulphates               0.579207
# alcohol                 0.960246
# quality                 0.787823
# Name: 4, dtype: float64

# %%
df_new=df[(z<3).all(axis=1)]
print("Old DataFrame", df.shape)
print("New DataFrame", df_new.shape)
print("total_drop_rows", df.shape[0] - df_new.shape[0])
# Out:
# Old DataFrame (1599, 10)
# New DataFrame (1465, 10)
# total_drop_rows 134

# %% [markdown]
# ## Percantage of data loss

# %%
loss_percentage = (1599-1465)/1599*100
print(loss_percentage, '%')
# Out:
# 8.380237648530331 %

# %%
#independent columns

x=df_new.iloc[:, :-1]

#Target

y=df_new.iloc[:, -1]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-1.52327786, -0.60997845, -0.14773633, ...,  1.35602874,
#         -0.58819698, -1.11263321],
#        [-1.52327786,  0.64918193,  0.98094663, ..., -0.80448789,
#          0.44776588, -0.52903433],
#        [-1.2437585 ,  0.20779788,  0.71393708, ..., -0.37606445,
#          0.21717855, -0.52903433],
#        ...,
#        [-0.66475575,  0.20779788, -0.14773633, ...,  0.74202064,
#          0.92521264,  0.73985972],
#        [-0.72596556, -0.37423055, -0.20988323, ...,  1.75965298,
#          0.6621594 , -0.03628211],
#        [ 1.06300751,  1.54450757, -0.74785836, ...,  0.53500831,
#          0.29593259,  0.73985972]])

# %%
pd.DataFrame(x).skew().sort_values()
# Out:
# 2   -0.116204
# 3   -0.020692
# 4   -0.005285
# 1   -0.002839
# 5   -0.001588
# 6    0.000086
# 0    0.019933
# 7    0.022818
# 8    0.107404
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.52327786, -0.60997845, -0.14773633, ...,  1.35602874,
#         -0.58819698, -1.11263321],
#        [-1.52327786,  0.64918193,  0.98094663, ..., -0.80448789,
#          0.44776588, -0.52903433],
#        [-1.2437585 ,  0.20779788,  0.71393708, ..., -0.37606445,
#          0.21717855, -0.52903433],
#        ...,
#        [-0.66475575,  0.20779788, -0.14773633, ...,  0.74202064,
#          0.92521264,  0.73985972],
#        [-0.72596556, -0.37423055, -0.20988323, ...,  1.75965298,
#          0.6621594 , -0.03628211],
#        [ 1.06300751,  1.54450757, -0.74785836, ...,  0.53500831,
#          0.29593259,  0.73985972]])

# %% [markdown]
# ## Transform Data to remove skewness

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Splitting the DataFrame

# %%
for i in range(0, 1500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i, test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1) == round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state", i, "The Model performs very well")
        print("At random_state:-", i)
        print("Training accuracy score is:-", accuracy_score(y_train,pred_train)*100)
        print("Training accuracy score is:-", accuracy_score(y_test, pred_test)*100, '\n')
# Out:
# At random state 4 The Model performs very well
# At random_state:- 4
# Training accuracy score is:- 60.40955631399317
# Training accuracy score is:- 60.40955631399317
#
# At random state 360 The Model performs very well
# At random_state:- 360
# Training accuracy score is:- 59.72696245733788
# Training accuracy score is:- 59.72696245733788
#
# At random state 402 The Model performs very well
# At random_state:- 402
# Training accuracy score is:- 60.068259385665534
# Training accuracy score is:- 60.068259385665534
#
# At random state 422 The Model performs very well
# At random_state:- 422
# Training accuracy score is:- 59.72696245733788
# Training accuracy score is:- 59.72696245733788
#
# At random state 693 The Model performs very well
# At random_state:- 693
# Training accuracy score is:- 59.72696245733788
# Training accuracy score is:- 59.72696245733788
#
# At random state 1333 The Model performs very well
# At random_state:- 1333
# Training accuracy score is:- 59.38566552901023
# Training accuracy score is:- 59.38566552901023
#
# At random state 1334 The Model performs very well
# At random_state:- 1334
# Training accuracy score is:- 60.75085324232082
# Training accuracy score is:- 60.75085324232082
#
# At random state 1345 The Model performs very well
# At random_state:- 1345
# Training accuracy score is:- 59.38566552901023
# Training accuracy score is:- 59.38566552901023
#
# At random state 1354 The Model performs very well
# At random_state:- 1354
# Training accuracy score is:- 58.95904436860068
# Training accuracy score is:- 59.044368600682596
#
# At random state 1438 The Model performs very well
# At random_state:- 1438
# Training accuracy score is:- 59.72696245733788
# Training accuracy score is:- 59.72696245733788

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20, random_state=402)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         8
#            5       0.40      0.42      0.41       124
#            6       0.36      0.40      0.38       121
#            7       0.14      0.10      0.12        39
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.35       293
#    macro avg       0.18      0.18      0.18       293
# weighted avg       0.34      0.35      0.34       293

# %% [markdown]
# ## Cross validation score for logistic regression

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At CV:-", j)
    print("cross Validation score is:-", lsc*100)
    print("accuracy_score is:-", lss*100)
    print('\n')
# Out:
# At CV:- 2
# cross Validation score is:- 54.33598729675933
# accuracy_score is:- 61.774744027303754
#
#
# At CV:- 3
# cross Validation score is:- 57.271586934415055
# accuracy_score is:- 61.774744027303754
#
#
# At CV:- 4
# cross Validation score is:- 57.75115022111046
# accuracy_score is:- 61.774744027303754
#
#
# At CV:- 5
# cross Validation score is:- 57.54266211604096
# accuracy_score is:- 61.774744027303754
#
#
# At CV:- 6
# cross Validation score is:- 58.982658637225384
# accuracy_score is:- 61.774744027303754
#
#
# At CV:- 7
# cross Validation score is:- 58.024281482928096
# accuracy_score is:- 61.774744027303754
#
#
# At CV:- 8
# cross Validation score is:- 58.50706818721787
# accuracy_score is:- 61.774744027303754
#
#
# At CV:- 9
# cross Validation score is:- 58.36005284994151
# accuracy_score is:- 61.774744027303754

# %%
lsscore_selected=cross_val_score(lr, x,y,cv=7).mean()
print("The CV score is",lsscore_selected,"\nThe accuracy score is",lss)
# Out:
# The CV score is 0.580242814829281
# The accuracy score is 0.6177474402730375

# %% [markdown]
# ## Random Forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_2 = RandomForestClassifier()

# %%
model_2.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model_2_train_pred = model_2.predict(x_train)

# %%
model_2_test_pred = model_2.predict(x_test)

# %%
print(classification_report(y_train, model_2_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       1.00      1.00      1.00        42
#            5       1.00      1.00      1.00       497
#            6       1.00      1.00      1.00       470
#            7       1.00      1.00      1.00       148
#            8       1.00      1.00      1.00        15
#
#     accuracy                           1.00      1172
#    macro avg       1.00      1.00      1.00      1172
# weighted avg       1.00      1.00      1.00      1172

# %%
print(classification_report(y_test, model_2_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         8
#            5       0.73      0.81      0.77       124
#            6       0.68      0.72      0.70       121
#            7       0.81      0.54      0.65        39
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.71       293
#    macro avg       0.44      0.41      0.42       293
# weighted avg       0.70      0.71      0.70       293

# %% [markdown]
# ## conclusion

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({'Original':a, 'Predicted':predicted}, index= range(len(a)))
df_com
# Out:
#      Original  Predicted
# 0           5          5
# 1           6          6
# 2           6          6
# 3           5          5
# 4           6          5
# ..        ...        ...
# 288         5          5
# 289         5          5
# 290         6          5
# 291         6          7
# 292         7          7
#
# [293 rows x 2 columns]
